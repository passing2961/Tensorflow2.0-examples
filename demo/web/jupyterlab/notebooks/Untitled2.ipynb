# %%
import json

with open('kepco.json', encoding='utf-8') as input_file:
    corpus = json.load(input_file)

# %%
sentences = []
for item in corpus:
    sentences.extend(item['sentences'])

# %%
len(sentences)
# Out:
# 2060

# %%
sentences
# Out:
# ['장애인인데 TV 수신료 면제를 받으려면 어떻게 해야 합니까?',
#  '장애인이 TV 수신료 면제를 받기 위해서는 어떻게 해야 하나요?',
#  '장애인이 TV 수신료 면제를 받기 위한 방법을 알고 싶습니다.',
#  '제가 살고 있는 지역이 난시청 지역인지 확인하려면 어떻게 해야 하나요?',
#  '현재 제가 사는 지역이 난시청 지역이 맞는지 확인하고 싶은데 방법을 알고 싶습니다.',
#  '난시청 지역이 제가 살고 있는 지역인지 알고 싶은데 어떻게 해야 합니까?',
#  '해외 출장등의 이유로 집을 오래 비워둘 예정입니다. 일시적으로 TV수신료 면제 받을 수 있나요?',
#  '개인 사정의 이유로 집을 오래 비우게 될 경우에는 TV수신료를 면제 받을 수 있나요?',
#  '해외 출장등의 이유로 집을 오래 비워두게 되면, 일시적으로 TV수신료가 면제 될까요?',
#  '개인의 소유지에 있는 전주를 옮기는데도 이설비용을 개인에게 부담시키는 이유가 무엇입니까?',
#  '개인 소유지에 있는 전주를 옮기는데도 이설비용을 왜 개인에게 부담을 주나요?',
#  '개인 소유의 전주를 옮겨도 이설비용이 개인에게 부담되는 이유가 궁금합니다.',
#  '건조물 신·증축을 위한 토지형질 변경공사에 지장이 되는 전선로의 이설비용은 누가 부담합니까?',
#  '건물 신·증축에 필요한 토지형질 변경공사에 영향을 끼치는 전선로의 이설비용은 누가 부담하나요?',
#  '전선로는 건물 신·증축을 위한 토지형질 변경공사에 영향을 끼치는데, 그 비용을 누가 부담하나요?',
#  '민원 신청 현황은 어디에서 확인할 수 있나요?',
#  '민원 신청 상황을 어디에서 볼 수 있나요?',
#  '민원 신청 현황을 확인할 수 있는 방법이 무엇인가요?',
#  '미리 전기요금을 납부하고 싶은데 가능한가요?',
#  '미리 전기요금을 납부하고 싶은데 가능합니까?',
#  '미리 전기요금을 지불하고 싶은데 가능한가요?',
#  '미리 전기요금을 지불하고 싶은데 가능합니까?',
# ...
